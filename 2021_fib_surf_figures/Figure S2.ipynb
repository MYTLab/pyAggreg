# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns

# %% [markdown]
# # Figure S2. (a) up

# %%
up_plot_data1 = np.loadtxt('plot_data/PMF/PMF_k10_relax_up_converage_1.txt')
up_plot_data2 = np.loadtxt('plot_data/PMF/PMF_k10_relax_up_converage_2.txt')
up_plot_data3 = np.loadtxt('plot_data/PMF/PMF_k10_relax_up_converage_3.txt')
up_plot_data4 = np.loadtxt('plot_data/PMF/PMF_k10_relax_up_converage_4.txt')
up_plot_data5 = np.loadtxt('plot_data/PMF/PMF_k10_relax_up_converage_5.txt')

# %%
up_distance1 = []
up_pmf1 = []
for i in np.arange(len(up_plot_data1)):
    up_distance1.append(up_plot_data1[i][0])
    up_pmf1.append(up_plot_data1[i][1])

up_distance2 = []
up_pmf2 = []
for i in np.arange(len(up_plot_data2)):
    up_distance2.append(up_plot_data2[i][0])
    up_pmf2.append(up_plot_data2[i][1])

up_distance3 = []
up_pmf3 = []
for i in np.arange(len(up_plot_data3)):
    up_distance3.append(up_plot_data3[i][0])
    up_pmf3.append(up_plot_data3[i][1])

up_distance4 = []
up_pmf4 = []
for i in np.arange(len(up_plot_data4)):
    up_distance4.append(up_plot_data4[i][0])
    up_pmf4.append(up_plot_data4[i][1])

up_distance5 = []
up_pmf5 = []
for i in np.arange(len(up_plot_data5)):
    up_distance5.append(up_plot_data5[i][0])
    up_pmf5.append(up_plot_data5[i][1])

# %%
x_pre1 = np.array(up_distance1)
y_pre1 = np.array(up_pmf1)
x_pre2 = np.array(up_distance2)
y_pre2 = np.array(up_pmf2)
x_pre3 = np.array(up_distance3)
y_pre3 = np.array(up_pmf3)
x_pre4 = np.array(up_distance4)
y_pre4 = np.array(up_pmf4)
x_pre5 = np.array(up_distance5)
y_pre5 = np.array(up_pmf5)


y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre1, y1,'s', label="502-1402 frames")
ax.plot(x_pre2, y2,'s', label="1402-2302 frames")
ax.plot(x_pre3, y3,'s', label="2302-3202 frames")
ax.plot(x_pre4, y4,'s', label="3202-4102 frames")
ax.plot(x_pre5, y5,'s', label="4102-5002 frames")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=17)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %%
y_dif1 = y_pre1.min() - y_pre1.max()
y_dif2 = y_pre2.min() - y_pre2.max()
y_dif3 = y_pre3.min() - y_pre3.max()
y_dif4 = y_pre4.min() - y_pre4.max()
y_dif5 = y_pre5.min() - y_pre5.max()
y_dif_all_up = [y_dif1-y_dif5,y_dif2-y_dif5,y_dif3-y_dif5,y_dif4-y_dif5,y_dif5-y_dif5]

# %% [markdown]
# # Figure S2. (b) back

# %%
back_plot_data1 = np.loadtxt('plot_data/PMF/PMF_k10_relax_back_converage_1.txt')
back_plot_data2 = np.loadtxt('plot_data/PMF/PMF_k10_relax_back_converage_2.txt')
back_plot_data3 = np.loadtxt('plot_data/PMF/PMF_k10_relax_back_converage_3.txt')
back_plot_data4 = np.loadtxt('plot_data/PMF/PMF_k10_relax_back_converage_4.txt')
back_plot_data5 = np.loadtxt('plot_data/PMF/PMF_k10_relax_back_converage_5.txt')

# %%
back_distance1 = []
back_pmf1 = []
for i in np.arange(len(back_plot_data1)):
    back_distance1.append(back_plot_data1[i][0])
    back_pmf1.append(back_plot_data1[i][1])

back_distance2 = []
back_pmf2 = []
for i in np.arange(len(back_plot_data2)):
    back_distance2.append(back_plot_data2[i][0])
    back_pmf2.append(back_plot_data2[i][1])

back_distance3 = []
back_pmf3 = []
for i in np.arange(len(back_plot_data3)):
    back_distance3.append(back_plot_data3[i][0])
    back_pmf3.append(back_plot_data3[i][1])

back_distance4 = []
back_pmf4 = []
for i in np.arange(len(back_plot_data4)):
    back_distance4.append(back_plot_data4[i][0])
    back_pmf4.append(back_plot_data4[i][1])

back_distance5 = []
back_pmf5 = []
for i in np.arange(len(back_plot_data5)):
    back_distance5.append(back_plot_data5[i][0])
    back_pmf5.append(back_plot_data5[i][1])

# %%
x_pre1 = np.array(back_distance1)
y_pre1 = np.array(back_pmf1)
x_pre2 = np.array(back_distance2)
y_pre2 = np.array(back_pmf2)
x_pre3 = np.array(back_distance3)
y_pre3 = np.array(back_pmf3)
x_pre4 = np.array(back_distance4)
y_pre4 = np.array(back_pmf4)
x_pre5 = np.array(back_distance5)
y_pre5 = np.array(back_pmf5)


y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre1, y1,'s', label="502-1402 frames")
ax.plot(x_pre2, y2,'s', label="1402-2302 frames")
ax.plot(x_pre3, y3,'s', label="2302-3202 frames")
ax.plot(x_pre4, y4,'s', label="3202-4102 frames")
ax.plot(x_pre5, y5,'s', label="4102-5002 frames")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=17)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %% [markdown]
# # Figure S2. (c) even-end

# %%
even_plot_data1 = np.loadtxt('plot_data/PMF/PMF_k10_relax_even_converage_1.txt')
even_plot_data2 = np.loadtxt('plot_data/PMF/PMF_k10_relax_even_converage_2.txt')
even_plot_data3 = np.loadtxt('plot_data/PMF/PMF_k10_relax_even_converage_3.txt')
even_plot_data4 = np.loadtxt('plot_data/PMF/PMF_k10_relax_even_converage_4.txt')
even_plot_data5 = np.loadtxt('plot_data/PMF/PMF_k10_relax_even_converage_5.txt')

# %%
even_distance1 = []
even_pmf1 = []
for i in np.arange(len(even_plot_data1)):
    even_distance1.append(even_plot_data1[i][0])
    even_pmf1.append(even_plot_data1[i][1])

even_distance2 = []
even_pmf2 = []
for i in np.arange(len(even_plot_data2)):
    even_distance2.append(even_plot_data2[i][0])
    even_pmf2.append(even_plot_data2[i][1])

even_distance3 = []
even_pmf3 = []
for i in np.arange(len(even_plot_data3)):
    even_distance3.append(even_plot_data3[i][0])
    even_pmf3.append(even_plot_data3[i][1])

even_distance4 = []
even_pmf4 = []
for i in np.arange(len(even_plot_data4)):
    even_distance4.append(even_plot_data4[i][0])
    even_pmf4.append(even_plot_data4[i][1])

even_distance5 = []
even_pmf5 = []
for i in np.arange(len(even_plot_data5)):
    even_distance5.append(even_plot_data5[i][0])
    even_pmf5.append(even_plot_data5[i][1])

# %%
x_pre1 = np.array(even_distance1)
y_pre1 = np.array(even_pmf1)
x_pre2 = np.array(even_distance2)
y_pre2 = np.array(even_pmf2)
x_pre3 = np.array(even_distance3)
y_pre3 = np.array(even_pmf3)
x_pre4 = np.array(even_distance4)
y_pre4 = np.array(even_pmf4)
x_pre5 = np.array(even_distance5)
y_pre5 = np.array(even_pmf5)


y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre1, y1,'s', label="502-1402 frames")
ax.plot(x_pre2, y2,'s', label="1402-2302 frames")
ax.plot(x_pre3, y3,'s', label="2302-3202 frames")
ax.plot(x_pre4, y4,'s', label="3202-4102 frames")
ax.plot(x_pre5, y5,'s', label="4102-5002 frames")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=17)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %%
y_dif1 = y_pre1.min() - y_pre1.max()
y_dif2 = y_pre2.min() - y_pre2.max()
y_dif3 = y_pre3.min() - y_pre3.max()
y_dif4 = y_pre4.min() - y_pre4.max()
y_dif5 = y_pre5.min() - y_pre5.max()
y_dif_all_even = [y_dif1-y_dif5,y_dif2-y_dif5,y_dif3-y_dif5,y_dif4-y_dif5,y_dif5-y_dif5]

# %% [markdown]
# # Figure S2. (d) down

# %%
down_plot_data1 = np.loadtxt('plot_data/PMF/PMF_k10_relax_down_converage_1.txt')
down_plot_data2 = np.loadtxt('plot_data/PMF/PMF_k10_relax_down_converage_2.txt')
down_plot_data3 = np.loadtxt('plot_data/PMF/PMF_k10_relax_down_converage_3.txt')
down_plot_data4 = np.loadtxt('plot_data/PMF/PMF_k10_relax_down_converage_4.txt')
down_plot_data5 = np.loadtxt('plot_data/PMF/PMF_k10_relax_down_converage_5.txt')

# %%
down_distance1 = []
down_pmf1 = []
for i in np.arange(len(down_plot_data1)):
    down_distance1.append(down_plot_data1[i][0])
    down_pmf1.append(down_plot_data1[i][1])

down_distance2 = []
down_pmf2 = []
for i in np.arange(len(down_plot_data2)):
    down_distance2.append(down_plot_data2[i][0])
    down_pmf2.append(down_plot_data2[i][1])

down_distance3 = []
down_pmf3 = []
for i in np.arange(len(down_plot_data3)):
    down_distance3.append(down_plot_data3[i][0])
    down_pmf3.append(down_plot_data3[i][1])

down_distance4 = []
down_pmf4 = []
for i in np.arange(len(down_plot_data4)):
    down_distance4.append(down_plot_data4[i][0])
    down_pmf4.append(down_plot_data4[i][1])

down_distance5 = []
down_pmf5 = []
for i in np.arange(len(down_plot_data5)):
    down_distance5.append(down_plot_data5[i][0])
    down_pmf5.append(down_plot_data5[i][1])

# %%
x_pre1 = np.array(down_distance1)
y_pre1 = np.array(down_pmf1)
x_pre2 = np.array(down_distance2)
y_pre2 = np.array(down_pmf2)
x_pre3 = np.array(down_distance3)
y_pre3 = np.array(down_pmf3)
x_pre4 = np.array(down_distance4)
y_pre4 = np.array(down_pmf4)
x_pre5 = np.array(down_distance5)
y_pre5 = np.array(down_pmf5)


y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre1, y1,'s', label="502-1402 frames")
ax.plot(x_pre2, y2,'s', label="1402-2302 frames")
ax.plot(x_pre3, y3,'s', label="2302-3202 frames")
ax.plot(x_pre4, y4,'s', label="3202-4102 frames")
ax.plot(x_pre5, y5,'s', label="4102-5002 frames")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=17)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %% [markdown]
# # Figure S2. (e) front

# %%
front_plot_data1 = np.loadtxt('plot_data/PMF/PMF_k10_relax_front_converage_1.txt')
front_plot_data2 = np.loadtxt('plot_data/PMF/PMF_k10_relax_front_converage_2.txt')
front_plot_data3 = np.loadtxt('plot_data/PMF/PMF_k10_relax_front_converage_3.txt')
front_plot_data4 = np.loadtxt('plot_data/PMF/PMF_k10_relax_front_converage_4.txt')
front_plot_data5 = np.loadtxt('plot_data/PMF/PMF_k10_relax_front_converage_5.txt')

# %%
front_distance1 = []
front_pmf1 = []
for i in np.arange(len(front_plot_data1)):
    front_distance1.append(front_plot_data1[i][0])
    front_pmf1.append(front_plot_data1[i][1])

front_distance2 = []
front_pmf2 = []
for i in np.arange(len(front_plot_data2)):
    front_distance2.append(front_plot_data2[i][0])
    front_pmf2.append(front_plot_data2[i][1])

front_distance3 = []
front_pmf3 = []
for i in np.arange(len(front_plot_data3)):
    front_distance3.append(front_plot_data3[i][0])
    front_pmf3.append(front_plot_data3[i][1])

front_distance4 = []
front_pmf4 = []
for i in np.arange(len(front_plot_data4)):
    front_distance4.append(front_plot_data4[i][0])
    front_pmf4.append(front_plot_data4[i][1])

front_distance5 = []
front_pmf5 = []
for i in np.arange(len(front_plot_data5)):
    front_distance5.append(front_plot_data5[i][0])
    front_pmf5.append(front_plot_data5[i][1])

# %%
x_pre1 = np.array(front_distance1)
y_pre1 = np.array(front_pmf1)
x_pre2 = np.array(front_distance2)
y_pre2 = np.array(front_pmf2)
x_pre3 = np.array(front_distance3)
y_pre3 = np.array(front_pmf3)
x_pre4 = np.array(front_distance4)
y_pre4 = np.array(front_pmf4)
x_pre5 = np.array(front_distance5)
y_pre5 = np.array(front_pmf5)


y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre1, y1,'s', label="502-1402 frames")
ax.plot(x_pre2, y2,'s', label="1402-2302 frames")
ax.plot(x_pre3, y3,'s', label="2302-3202 frames")
ax.plot(x_pre4, y4,'s', label="3202-4102 frames")
ax.plot(x_pre5, y5,'s', label="4102-5002 frames")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=17)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %%
y_dif1 = y_pre1.min() - y_pre1.max()
y_dif2 = y_pre2.min() - y_pre2.max()
y_dif3 = y_pre3.min() - y_pre3.max()
y_dif4 = y_pre4.min() - y_pre4.max()
y_dif5 = y_pre5.min() - y_pre5.max()
y_dif_all_front = [y_dif1-y_dif5,y_dif2-y_dif5,y_dif3-y_dif5,y_dif4-y_dif5,y_dif5-y_dif5]

# %% [markdown]
# # Figure S2. (f) odd-end

# %%
odd_plot_data1 = np.loadtxt('plot_data/PMF/PMF_k10_relax_odd_converage_1.txt')
odd_plot_data2 = np.loadtxt('plot_data/PMF/PMF_k10_relax_odd_converage_2.txt')
odd_plot_data3 = np.loadtxt('plot_data/PMF/PMF_k10_relax_odd_converage_3.txt')
odd_plot_data4 = np.loadtxt('plot_data/PMF/PMF_k10_relax_odd_converage_4.txt')
odd_plot_data5 = np.loadtxt('plot_data/PMF/PMF_k10_relax_odd_converage_5.txt')

# %%
odd_distance1 = []
odd_pmf1 = []
for i in np.arange(len(odd_plot_data1)):
    odd_distance1.append(odd_plot_data1[i][0])
    odd_pmf1.append(odd_plot_data1[i][1])

odd_distance2 = []
odd_pmf2 = []
for i in np.arange(len(odd_plot_data2)):
    odd_distance2.append(odd_plot_data2[i][0])
    odd_pmf2.append(odd_plot_data2[i][1])

odd_distance3 = []
odd_pmf3 = []
for i in np.arange(len(odd_plot_data3)):
    odd_distance3.append(odd_plot_data3[i][0])
    odd_pmf3.append(odd_plot_data3[i][1])

odd_distance4 = []
odd_pmf4 = []
for i in np.arange(len(odd_plot_data4)):
    odd_distance4.append(odd_plot_data4[i][0])
    odd_pmf4.append(odd_plot_data4[i][1])

odd_distance5 = []
odd_pmf5 = []
for i in np.arange(len(odd_plot_data5)):
    odd_distance5.append(odd_plot_data5[i][0])
    odd_pmf5.append(odd_plot_data5[i][1])

# %%
x_pre1 = np.array(odd_distance1)
y_pre1 = np.array(odd_pmf1)
x_pre2 = np.array(odd_distance2)
y_pre2 = np.array(odd_pmf2)
x_pre3 = np.array(odd_distance3)
y_pre3 = np.array(odd_pmf3)
x_pre4 = np.array(odd_distance4)
y_pre4 = np.array(odd_pmf4)
x_pre5 = np.array(odd_distance5)
y_pre5 = np.array(odd_pmf5)


y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre1, y1,'s', label="502-1402 frames")
ax.plot(x_pre2, y2,'s', label="1402-2302 frames")
ax.plot(x_pre3, y3,'s', label="2302-3202 frames")
ax.plot(x_pre4, y4,'s', label="3202-4102 frames")
ax.plot(x_pre5, y5,'s', label="4102-5002 frames")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=17)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %% [markdown]
# # Figure S2. (g) Free energy profiles of all 6 orientations

# %%
x_pre = np.array(up_distance5)
y_pre = np.array(up_pmf5)
x_pre1 = np.array(back_distance5)
y_pre1 = np.array(back_pmf5)
x_pre2 = np.array(down_distance5)
y_pre2 = np.array(down_pmf5)
x_pre3 = np.array(even_distance5)
y_pre3 = np.array(even_pmf5)
x_pre4 = np.array(front_distance5)
y_pre4 = np.array(front_pmf5)
x_pre5 = np.array(odd_distance5)
y_pre5 = np.array(odd_pmf5)

y = y_pre - y_pre.max()
y1 = y_pre1 - y_pre1.max()
y2 = y_pre2 - y_pre2.max()
y3 = y_pre3 - y_pre3.max()
y4 = y_pre4 - y_pre4.max()
y5 = y_pre5 - y_pre5.max()

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(x_pre, y,'s', label="up")
ax.plot(x_pre1, y1,'s', label="back")
ax.plot(x_pre2, y2,'s', label="down")
ax.plot(x_pre3, y3,'s', label="even")
ax.plot(x_pre4, y4,'s', label="front")
ax.plot(x_pre5, y5,'s', label="odd")

ax.set_xlabel(r"$r$ / nm", fontsize=20)
ax.set_ylabel(r"Free energy / kcal/mol", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=16)
ax.set_title("Potential of mean force", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Potential of mean force')

# %% [markdown]
# # Figure S2. (h) Convergence test on the bootstrapping

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.plot([500,1400,2300,3200,4100], y_dif_all_front, label="front", linewidth=5)
ax.plot([500,1400,2300,3200,4100], y_dif_all_up, label="up", linewidth=5)
ax.plot([500,1400,2300,3200,4100], y_dif_all_even, label="even", linewidth=5)


ax.set_xlabel(r"frames", fontsize=20)
ax.set_ylabel(r"$\Delta$F / kcal/mol", fontsize=20)
plt.xticks([500,1400,2300,3200,4100], fontsize=18)
plt.yticks(fontsize=18)

#plt.xlim(0,10)

ax.legend(fancybox=True, fontsize=16)
ax.set_title(r"$\Delta$F for different frames", fontsize=25)
# Out:
# Text(0.5, 1.0, '$\\Delta$F for different frames')
