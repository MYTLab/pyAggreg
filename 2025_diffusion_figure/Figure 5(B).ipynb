# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pyemma
import os
from pyemma.util.contexts import settings
import seaborn as sns

# %%
NF_s_para = np.loadtxt('plot_data/Free_diffusion/NF_61ch_s_M_para.txt')

# %%
CF_s_para = np.loadtxt('plot_data/Free_diffusion/CF_61ch_s_M_para.txt')

# %%
# Your existing code
fig, ax = plt.subplots(figsize=(10, 6))  # Adjust the figsize as needed

ax.plot(NF_s_para, linewidth=3, label='Parallel monomer (N-ter surface)', color='blue')
ax.plot(CF_s_para, linewidth=3, label='Parallel monomer (C-ter surface)', color='red')

# Set font size for y-axis offset text
ax.yaxis.get_offset_text().set_fontsize(16)  # Adjust the fontsize as needed

# Your existing code continued
x1 = np.arange(15, len(array1))
m1, b1 = np.polyfit(x1, array1[15:], 1)

x2 = np.arange(15, len(array_s_para))
m2, b2 = np.polyfit(x2, array_s_para[15:], 1)

ax.plot(x1, m1 * x1 + b1, linewidth=5, linestyle='dashed', color='blue')
ax.plot(x2, m2 * x2 + b2, linewidth=5, linestyle='dashed', color='red')

ax.tick_params(axis='both', which='major', labelsize=18)  # Adjust the fontsize as needed
ax.set_ylabel(r"$<(r-r(0))^2>(cm^2)$", fontsize=22)  # Adjust the fontsize as needed
ax.set_xlabel(r"Simulation time steps ($\times 10^6$)", fontsize=22)  # Adjust the fontsize as needed

# 添加灰色色塊
plt.axvspan(0, 15, color='gray', alpha=0.5)

ax.legend(fontsize=16)  # Adjust the fontsize as needed
plt.title("MSD", fontsize=24)
plt.xlim(left=0)
# Show the plot
plt.show()
